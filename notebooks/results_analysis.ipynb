# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path_to_data = "../data/"

# %%
filename = "1_GA_SimpleCities_001_Results.csv"

dataframe = pd.read_csv(path_to_data + filename)
dataframe.head()
# Out:
#    unique_id  generation  average_fitness  best_fitness
# 0          1           1         0.000356      0.000503
# 1          1           2         0.000358      0.000503
# 2          1           3         0.000359      0.000512
# 3          1           4         0.000360      0.000512
# 4          1           5         0.000360      0.000512

# %%
filename2 = "2_GA_SimpleCities_002_Results.csv"

dataframe2 = pd.read_csv(path_to_data + filename2)
dataframe2.head()
# Out:
#    unique_id  generation  average_fitness  best_fitness
# 0          2           1         0.000369      0.000586
# 1          2           2         0.000369      0.000586
# 2          2           3         0.000371      0.000586
# 3          2           4         0.000371      0.000586
# 4          2           5         0.000373      0.000586

# %%
filename3 = "3_GA_SimpleCities_003_Results.csv"

dataframe3 = pd.read_csv(path_to_data + filename3)
dataframe3.head()
# Out:
#    unique_id  generation  average_fitness  best_fitness
# 0          3           1         0.000362      0.000599
# 1          3           2         0.000363      0.000599
# 2          3           3         0.000365      0.000599
# 3          3           4         0.000366      0.000599
# 4          3           5         0.000367      0.000599

# %%
filename4 = "4_GA_SimpleCities_004_Results.csv"

dataframe4 = pd.read_csv(path_to_data + filename4)
dataframe4.head()
# Out:
#    unique_id  generation  average_fitness  best_fitness
# 0          4           1         0.000363      0.000547
# 1          4           2         0.000363      0.000547
# 2          4           3         0.000364      0.000547
# 3          4           4         0.000366      0.000547
# 4          4           5         0.000368      0.000573

# %%
filename5 = "5_GA_SimpleCities_005_Results.csv"

dataframe5 = pd.read_csv(path_to_data + filename5)
dataframe5.head()
# Out:
#    unique_id  generation  average_fitness  best_fitness
# 0          5           1         0.000355      0.000503
# 1          5           2         0.000357      0.000503
# 2          5           3         0.000357      0.000503
# 3          5           4         0.000358      0.000503
# 4          5           5         0.000359      0.000503

# %%
filename6 = "6_GA_SimpleCities_006_Results.csv"

dataframe6 = pd.read_csv(path_to_data + filename6)
dataframe6.head()
# Out:
#    unique_id  generation  average_fitness  best_fitness
# 0          6           1         0.000365      0.000599
# 1          6           2         0.000365      0.000599
# 2          6           3         0.000365      0.000599
# 3          6           4         0.000365      0.000599
# 4          6           5         0.000365      0.000599

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

sns.lineplot(data=dataframe, x="generation", y="average_fitness", label="1,100,40,0.6,1", ax=axs[0])
sns.lineplot(data=dataframe, x="generation", y="best_fitness", label="1,100,40,0.6,1", ax=axs[1])
sns.lineplot(data=dataframe2, x="generation", y="average_fitness", label="2,100,40,0.1,1", ax=axs[0])
sns.lineplot(data=dataframe2, x="generation", y="best_fitness", label="2,100,40,0.1,1", ax=axs[1])
sns.lineplot(data=dataframe3, x="generation", y="average_fitness", label="3,100,20,0.6,1", ax=axs[0])
sns.lineplot(data=dataframe3, x="generation", y="best_fitness", label="3,100,20,0.6,1", ax=axs[1])
sns.lineplot(data=dataframe4, x="generation", y="average_fitness", label="4,100,40,0.6,1", ax=axs[0])
sns.lineplot(data=dataframe4, x="generation", y="best_fitness", label="4,100,40,0.6,1", ax=axs[1])
sns.lineplot(data=dataframe5, x="generation", y="average_fitness", label="5,100,40,0.1,1", ax=axs[0])
sns.lineplot(data=dataframe5, x="generation", y="best_fitness", label="5,100,40,0.1,1", ax=axs[1])
sns.lineplot(data=dataframe6, x="generation", y="average_fitness", label="6,50000,40,0.1,1", ax=axs[0])
sns.lineplot(data=dataframe6, x="generation", y="best_fitness", label="6,50000,40,0.1,1", ax=axs[1])

axs[0].set_title("Average Fitness")
axs[1].set_title("Best Fitness")
plt.legend()
plt.show()

# %% [markdown]
# WHAT DOES THOSE RESULTS TELL US?
# - There is a couple of lucky runs where we directly found the best fitness (1, 3 & 6)
# - Having a larger mutation rate seems to give us a best fitness quicker, however having a smaller mutation rate seems to allow for a more steady and natural progression towards a better average fitness and best fitness. Mutation rate directly affects diversity.
# - The pool size seems to affect diversity too as we can see from example 6.
