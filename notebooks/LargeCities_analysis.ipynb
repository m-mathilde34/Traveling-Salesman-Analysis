# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path_to_data = "../data/"

# %%
filename = "11_GA_LargeCities_011_Results.csv"

dataframe = pd.read_csv(path_to_data + filename)
dataframe.head()
# Out:
#    unique_id  generation  average_fitness  best_fitness
# 0         11           1         0.000055      0.000065
# 1         11           2         0.000055      0.000065
# 2         11           3         0.000056      0.000065
# 3         11           4         0.000056      0.000065
# 4         11           5         0.000056      0.000065

# %%
filename2 = "12_GA_LargeCities_012_Results.csv"

dataframe2 = pd.read_csv(path_to_data + filename2)
dataframe2.head()
# Out:
#    unique_id  generation  average_fitness  best_fitness
# 0         12           1         0.000056      0.000066
# 1         12           2         0.000056      0.000066
# 2         12           3         0.000056      0.000066
# 3         12           4         0.000056      0.000067
# 4         12           5         0.000056      0.000067

# %%
filename3 = "13_GA_LargeCities_013_Results.csv"

dataframe3 = pd.read_csv(path_to_data + filename3)
dataframe3.head()
# Out:
#    unique_id  generation  average_fitness  best_fitness
# 0         13           1         0.000055      0.000063
# 1         13           2         0.000055      0.000063
# 2         13           3         0.000056      0.000063
# 3         13           4         0.000056      0.000063
# 4         13           5         0.000056      0.000063

# %%
filename4 = "14_GA_LargeCities_014_Results.csv"

dataframe4 = pd.read_csv(path_to_data + filename4)
dataframe4.head()
# Out:
#    unique_id  generation  average_fitness  best_fitness
# 0         14           1         0.000055      0.000067
# 1         14           2         0.000055      0.000067
# 2         14           3         0.000055      0.000067
# 3         14           4         0.000056      0.000067
# 4         14           5         0.000056      0.000067

# %%
filename5 = "15_GA_LargeCities_015_Results.csv"

dataframe5 = pd.read_csv(path_to_data + filename5)
dataframe5.head()
# Out:
#    unique_id  generation  average_fitness  best_fitness
# 0         15           1         0.000056      0.000071
# 1         15           2         0.000056      0.000071
# 2         15           3         0.000056      0.000071
# 3         15           4         0.000056      0.000071
# 4         15           5         0.000056      0.000071

# %%
filename6 = "16_GA_LargeCities_016_Results.csv"

dataframe6 = pd.read_csv(path_to_data + filename6)
dataframe6.head()
# Out:
#    unique_id  generation  average_fitness  best_fitness
# 0         16           1         0.000056      0.000073
# 1         16           2         0.000056      0.000073
# 2         16           3         0.000056      0.000073
# 3         16           4         0.000056      0.000073
# 4         16           5         0.000056      0.000073

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

sns.lineplot(data=dataframe, x="generation", y="average_fitness", label="1,100,40,0.6,1", ax=axs[0])
sns.lineplot(data=dataframe, x="generation", y="best_fitness", label="1,100,40,0.6,1", ax=axs[1])

sns.lineplot(data=dataframe2, x="generation", y="average_fitness", label="2,100,40,0.1,1", ax=axs[0])
sns.lineplot(data=dataframe2, x="generation", y="best_fitness", label="2,100,40,0.1,1", ax=axs[1])

sns.lineplot(data=dataframe3, x="generation", y="average_fitness", label="3,100,20,0.1,1", ax=axs[0])
sns.lineplot(data=dataframe3, x="generation", y="best_fitness", label="3,100,20,0.1,1", ax=axs[1])

sns.lineplot(data=dataframe4, x="generation", y="average_fitness", label="4,100,20,0.6,1", ax=axs[0])
sns.lineplot(data=dataframe4, x="generation", y="best_fitness", label="4,100,20,0.6,1", ax=axs[1])

sns.lineplot(data=dataframe5, x="generation", y="average_fitness", label="5,50000,40,0.1,1", ax=axs[0])
sns.lineplot(data=dataframe5, x="generation", y="best_fitness", label="5,50000,40,0.1,1", ax=axs[1])

sns.lineplot(data=dataframe6, x="generation", y="average_fitness", label="6,50000,20000,0.1,1", ax=axs[0])
sns.lineplot(data=dataframe6, x="generation", y="best_fitness", label="6,50000,20000,0.1,1", ax=axs[1])

axs[0].set_title("Average Fitness")
axs[1].set_title("Best Fitness")
plt.legend()
plt.show()
